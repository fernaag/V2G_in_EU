# %% [markdown]
# ## Scenario comparison: Mass and Energy

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams.update({'font.size': 12})

# %%
cmap_mat = mpl.cm.get_cmap('Paired')
cmap_ener = mpl.cm.get_cmap('Accent')

# %%
# read data directly from capacity and material excel sheets into a single dataframe
# - data names
dict_names = {'material_use': ['Primary materials', 'Secondary materials', 'Reused batteries', 'New batteries'],\
              'total_capacity': ['EV fleet', 'V2G', 'Reused batteries', 'New batteries']}
# - dataframe structure
df = pd.read_excel('material_use.xlsx', sheet_name = 'Primary materials', header = 0, usecols = "B:E", engine = 'openpyxl')
# - add data
for my_key in dict_names.keys():
    for my_name in dict_names[my_key]:
        # - naming conventions - materials
        if my_key == 'material_use':
            if my_name == 'Primary materials':
                my_col = 'Raw materials'
            elif my_name == 'Secondary materials':
                my_col = 'Recycled materials'
            elif my_name == 'New batteries':
                my_col = 'NSB materials'
            elif my_name == 'Reused batteries':
                my_col = 'Reused materials'
            else:
                my_col = my_name
        # - naming conventions - energy
        elif my_key == 'total_capacity':
            if my_name == 'Reused batteries':
                my_col = "SLB"
            elif my_name == 'New batteries':
                my_col = "NSB"
            else:
                my_col = my_name
        # - add data
        df[my_col] = pd.read_excel(my_key+'.xlsx', sheet_name = my_name, header = 0, usecols = "F", engine = 'openpyxl')
# add total material demand
# add total demand
df['Total materials'] =  df['Raw materials'] + df['Recycled materials']

# %%
# sort the dataframe
df_sorted = pd.DataFrame(columns = df.columns)
# loop over scenarios
for evs in ['Fast EV', 'Slow EV']:
    for sds in ['CP4All', 'High', 'Low']:
        for rs in ['No reuse', 'LFP reused', 'All reused']:
            for v2gs in ['No V2G', 'Low', 'Medium', 'V2G mandate']:
                df_sorted.loc[len(df_sorted.index)] = \
                list(\
                df[(df['EV Scenario'] == evs) \
                   & (df['Storage Demand Scenario'] == sds) \
                   & (df['Reuse Scenario'] == rs) \
                   & (df['V2G Scenario'] == v2gs)].values[0])

# %%
df_sorted
# Out:
#    EV Scenario Reuse Scenario V2G Scenario Storage Demand Scenario  \
# 0      Fast EV       No reuse       No V2G                  CP4All
# 1      Fast EV       No reuse          Low                  CP4All
# 2      Fast EV       No reuse       Medium                  CP4All
# 3      Fast EV       No reuse  V2G mandate                  CP4All
# 4      Fast EV     LFP reused       No V2G                  CP4All
# ..         ...            ...          ...                     ...
# 67     Slow EV     LFP reused  V2G mandate                     Low
# 68     Slow EV     All reused       No V2G                     Low
# 69     Slow EV     All reused          Low                     Low
# 70     Slow EV     All reused       Medium                     Low
# 71     Slow EV     All reused  V2G mandate                     Low
#
#     Raw materials  Recycled materials  Reused materials  NSB materials  \
# 0    40219.582958         8558.998068          0.000000    2548.268879
# 1    38795.959959         8425.182151          0.000000     990.829962
# 2    38067.706829         8293.739857          0.000000     131.134538
# 3    38050.318319         8285.815001          0.000000     105.821172
# 4    39524.335872         8054.869171       3041.762420    1348.892894
# ..            ...                 ...               ...            ...
# 67   32928.596020         4709.463968         49.376163      79.777700
# 68   33330.000885         4394.897061       2212.566939     166.615658
# 69   32931.168529         4703.009090        452.597643      75.895332
# 70   32894.556326         4689.725415        225.151146      25.999453
# 71   32888.873075         4687.199938        187.956258      17.790726
#
#         EV fleet          V2G          SLB          NSB  Total materials
# 0   27292.176584     0.000000     0.000000  1636.483421     48778.581027
# 1   27292.176584  1077.506019     0.000000   636.305226     47221.142110
# 2   27292.176584  1743.959216     0.000000    84.213836     46361.446686
# 3   27292.176584  1763.772118     0.000000    67.957740     46336.133320
# 4   27292.176584     0.000000  1411.309400   866.251154     47579.205042
# ..           ...          ...          ...          ...              ...
# 67  22171.707561   521.955135    22.670131    51.232774     37638.059988
# 68  22171.707561     0.000000  1004.875054   106.999605     37724.897946
# 69  22171.707561   452.761836   190.774917    48.739540     37634.177620
# 70  22171.707561   536.361368    92.302657    16.696697     37584.281741
# 71  22171.707561   549.701646    76.643121    11.425101     37576.073014
#
# [72 rows x 13 columns]

# %%
# with pd.option_context('display.max_rows', None,
#                        'display.max_columns', None,
#                        'display.precision', 20,
#                        ):
#     print(df_ascend_rawm)

# %%
# Plot (materials)
fig = plt.figure(figsize=[15, 5], facecolor ='white')
transp = 1   
for ev_scenario in ['Slow EV', 'Fast EV']:
    if ev_scenario == 'Slow EV':
        pmarker = 'x'
        ev_label = 'Projected'
    if ev_scenario == 'Fast EV':
        pmarker = 'o'
        ev_label = 'Fast'
    for col in ['Total materials', 'Raw materials', 'Recycled materials', 'Reused materials', 'NSB materials']:
        if col == 'Total materials':
            pcolor = np.array([cmap_mat(4)])
            plabel = 'Total'
        if col == 'Raw materials':
            # pcolor = 'tab:grey'
            pcolor = np.array([cmap_mat(0)])
            # plabel = 'Raw'
            plabel = 'Primary'
        if col == 'Recycled materials':
            # pcolor = 'tab:green'
            pcolor = np.array([cmap_mat(1)])
            plabel = 'Recycled'
        if col == 'Reused materials':
            # pcolor = 'tab:blue'
            pcolor = np.array([cmap_ener(1)])
            plabel = 'Reused'
        if col == 'NSB materials':
            # pcolor = 'tab:orange'
            pcolor = np.array([cmap_ener(2)])
            plabel = 'NSB'
        # plot
        plt.scatter(df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].index,\
                    df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
# beautification
plt.grid()
plt.xticks(np.arange(0, 150, 4))
plt.xlim((0, 72))
plt.yticks(np.arange(0, 100, 5))
plt.ylim((0,50))
plt.xlabel('Scenarios')
plt.ylabel('Mass (Mt)')
plt.legend(loc = 'upper left', title = 'Materials (EV Scenario)', bbox_to_anchor=(1,1))
plt.title('B: Materials use by scenario')
plt.savefig('mass_by_scenario_ordered.png', dpi = 600, bbox_inches = 'tight')

# %%
# Plot (materials with line break) (https://matplotlib.org/stable/gallery/subplots_axes_and_figures/broken_axis.html, 
# https://thepythonyouneed.com/how-to-hide-the-axes-spines-of-a-plot-with-matplotlib-using-python/)
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 5], facecolor ='white', gridspec_kw={'height_ratios': [1, 3]})
fig.subplots_adjust(hspace=0.05)  # adjust space between axes

# plot the same data on both axes
transp = 1   
for ev_scenario in ['Slow EV', 'Fast EV']:
    if ev_scenario == 'Slow EV':
        pmarker = 'x'
        ev_label = 'Projected'
    if ev_scenario == 'Fast EV':
        pmarker = 'o'
        ev_label = 'Fast'
    for col in ['Total materials', 'Raw materials', 'Recycled materials', 'Reused materials', 'NSB materials']:
        if col == 'Total materials':
                    pcolor = np.array([cmap_mat(4)])
                    plabel = 'Total'
        if col == 'Raw materials':
            # pcolor = 'tab:grey'
            pcolor = np.array([cmap_mat(0)])
            # plabel = 'Raw'
            plabel = 'Primary'
        if col == 'Recycled materials':
            # pcolor = 'tab:green'
            pcolor = np.array([cmap_mat(1)])
            plabel = 'Recycled'
        if col == 'Reused materials':
            # pcolor = 'tab:blue'
            pcolor = np.array([cmap_ener(1)])
            plabel = 'Reused'
        if col == 'NSB materials':
            # pcolor = 'tab:orange'
            pcolor = np.array([cmap_ener(2)])
            plabel = 'NSB'
        # plot
        ax1.scatter(df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].index,\
                    df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
        ax2.scatter(df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].index,\
                    df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
        
# zoom-in / limit the view to different portions of the data
ax1.set_ylim(27,50)  # outliers only
ax2.set_ylim(0, 9)  # most of the data

# hide the spines between ax and ax2
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

# Now, let's turn towards the cut-out slanted lines.
# We create line objects in axes coordinates, in which (0,0), (0,1),
# (1,0), and (1,1) are the four corners of the axes.
# The slanted lines themselves are markers at those locations, such that the
# lines keep their angle and position, independent of the axes size or scale
# Finally, we need to disable clipping.

d = .5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

# beautification
ax1.grid(), ax2.grid()
#ax1.set_yticks([1150, 1700])
plt.xticks(np.arange(0, 150, 4))
plt.xlim((0, 72))
#plt.yticks(np.arange(0, 5, 0.5))
#plt.ylim((0,3.5))
plt.xlabel('Scenarios')
# plt.ylabel('Capacity (TWh)')
fig.text(0.08, 0.5, 'Storage capacity (TWh)', ha='center', va='center', rotation='vertical')
plt.legend(loc = 'upper left', title = 'Materials (EV Scenario)', bbox_to_anchor=(1.01,1.3))
ax1.set_title('B: Materials use by scenario')
plt.savefig('mass_by_scenario_ordered.png', dpi = 600, bbox_inches = 'tight')

# %%
df_ascend_rawm['V2G+SLB+NSB'] = df_ascend_rawm['V2G'] + df_ascend_rawm['SLB'] + df_ascend_rawm['NSB']

# %%
df_V2G_ratio = df_ascend_rawm['V2G'] / df_ascend_rawm['V2G+SLB+NSB']
df_V2G_ratio.sort_values(ascending = False, inplace = True)

# %%
plt.plot(df_V2G_ratio.values)
plt.grid()

# %%
df_V2G_ratio[df_V2G_ratio > 0.50].count() / len(df_V2G_ratio)
# Out:
# 0.7222222222222222

# %%
# Plot (storage capacity) (https://matplotlib.org/stable/gallery/subplots_axes_and_figures/broken_axis.html, 
# https://thepythonyouneed.com/how-to-hide-the-axes-spines-of-a-plot-with-matplotlib-using-python/)
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=[15, 5], facecolor ='white', gridspec_kw={'height_ratios': [1, 3]})
fig.subplots_adjust(hspace=0.05)  # adjust space between axes

# plot the same data on both axes
transp = 1   
for ev_scenario in ['Slow EV', 'Fast EV']:
    if ev_scenario == 'Slow EV':
        pmarker = 'x'
        ev_label = 'Projected'
    if ev_scenario == 'Fast EV':
        pmarker = 'o'
        ev_label = 'Fast'
    for col in ['EV fleet', 'V2G', 'SLB', 'NSB']:
        if col == 'EV fleet':
            pcolor = 'tab:grey'
            plabel = 'EV fleet'
        if col == 'V2G':
            # pcolor = 'tab:green'
            pcolor = np.array([cmap_ener(0)])
            plabel = 'V2G'
        if col == 'SLB':
            # pcolor = 'tab:blue'
            pcolor = np.array([cmap_ener(1)])
            plabel = 'SLB'
        if col == 'NSB':
            # pcolor = 'tab:orange'
            pcolor = np.array([cmap_ener(2)])
            plabel = 'NSB'
        # plot
        ax1.scatter(df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].index,\
                    df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
        ax2.scatter(df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].index,\
                    df_sorted.loc[df_sorted['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
        
# zoom-in / limit the view to different portions of the data
ax1.set_ylim(15,35)  # outliers only
ax2.set_ylim(0, 3.2)  # most of the data

# hide the spines between ax and ax2
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

# Now, let's turn towards the cut-out slanted lines.
# We create line objects in axes coordinates, in which (0,0), (0,1),
# (1,0), and (1,1) are the four corners of the axes.
# The slanted lines themselves are markers at those locations, such that the
# lines keep their angle and position, independent of the axes size or scale
# Finally, we need to disable clipping.

d = .5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

# beautification
ax1.grid(), ax2.grid()
#ax1.set_yticks([1150, 1700])
plt.xticks(np.arange(0, 150, 4))
plt.xlim((0, 72))
#plt.yticks(np.arange(0, 5, 0.5))
#plt.ylim((0,3.5))
plt.xlabel('Scenarios')
# plt.ylabel('Capacity (TWh)')
fig.text(0.08, 0.5, 'Storage capacity (TWh)', ha='center', va='center', rotation='vertical')
plt.legend(loc = 'upper left', title = 'Storage (EV Scenario)', bbox_to_anchor=(1.01,1.3))
ax1.set_title('A: Storage capacity by scenario')
plt.savefig('storage_capacity_by_scenario_sorted.png', dpi = 600, bbox_inches = 'tight')

# %%
# Plot (storage capacity)
fig = plt.figure(figsize=[15, 5], facecolor ='white')
transp = 0.9     
for ev_scenario in ['Slow EV', 'Fast EV']:
    if ev_scenario == 'Slow EV':
        pmarker = 'x'
        ev_label = 'Projected'
    if ev_scenario == 'Fast EV':
        pmarker = 'o'
        ev_label = 'Fast'
    for col in ['EV fleet', 'V2G', 'SLB', 'NSB']:
        if col == 'EV fleet':
            pcolor = 'tab:grey'
            plabel = 'EV fleet'
        if col == 'V2G':
            pcolor = 'tab:green'
            plabel = 'V2G'
        if col == 'SLB':
            pcolor = 'tab:blue'
            plabel = 'SLB'
        if col == 'NSB':
            pcolor = 'tab:orange'
            plabel = 'NSB'
        # plot
        plt.scatter(df_ascend_rawm.loc[df_ascend_rawm['EV Scenario'] == ev_scenario, col].index,\
                    df_ascend_rawm.loc[df_ascend_rawm['EV Scenario'] == ev_scenario, col].values/1000,\
                    marker = pmarker, label = plabel+' ('+ev_label+')', alpha = transp, linewidth = 2, c = pcolor)
# beautification
plt.grid()
plt.xticks(np.arange(0, 150, 5))
plt.xlim((0, 72))
plt.yticks(np.arange(0, 5, 0.5))
plt.ylim((0,4))
plt.xlabel('Scenarios')
plt.ylabel('Capacity (TWh)')
plt.legend(loc = 'upper left', title = 'Storage (EV Scenario)', bbox_to_anchor=(1,1))
plt.title('Storage capacity by scenario')
plt.savefig('storage_capacity_by_scenario_2.png', dpi = 300, bbox_inches = 'tight')
